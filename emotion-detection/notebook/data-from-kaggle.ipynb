# %%
import kagglehub
import os
import shutil

# Create the data directory if it doesn't exist
os.makedirs('dataset/', exist_ok=True)

# Download latest version
download_path = kagglehub.dataset_download(
    "jonathanoheix/face-expression-recognition-dataset"
)

print("Path to dataset files:", download_path)

shutil.move(download_path,'dataset/')
# Out:
# Path to dataset files: /Users/hieutrinh358/.cache/kagglehub/datasets/jonathanoheix/face-expression-recognition-dataset/versions/1
# 'dataset/1'
